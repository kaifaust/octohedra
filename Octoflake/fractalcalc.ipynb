# %%
from collections import namedtuple

# %%
stats = dict()

Bom = namedtuple("Bom",['edgeLength','nodes','edges'])

first = Bom(edgeLength = 1, nodes = 8, edges = 12)


def nextIteration(bom):
    
    
#     bottom_nodes = (bom.edgeLength + 1) ** 2 * 4 - 4 * (bom.edgeLength + 1) +1

    naive = 6* bom
    print(naive)
    
    
    bottom_edges = 4 * bom.edges - 4 * bom.edgeLength
    inverted_edges = bom.edges - 4 * bom.edgeLength
    top_edges = bom.edges - 2 * (bom.edgeLength * (bom.edgeLength + 1))
    
    
    edges =  bottom_edges + inverted_edges

# %%
stats = dict()

Bom = namedtuple("Bom",['edgeLength','nodes','edges'])

first = Bom(edgeLength = 1, nodes = 6, edges = 12)


def nextIteration(last):
    
    next_edge_length = 2 * last.edgeLength

    
    naive_nodes = 6 * last.nodes
    naive_edges = 6 * last.edges
    
    duplicate_nodes = 6 * next_edge_length + 5
    duplicate_edges = 6 * next_edge_length
    
    next_nodes = naive_nodes - duplicate_nodes
    next_edges = naive_edges - duplicate_edges
    
    #print(f"{naive_nodes=}, {duplicate_nodes=}, {next_nodes=}")
    #print(f"{naive_edges=}, {duplicate_edges=}, {next_edges=}")
    
    

    
    return Bom(edgeLength = next_edge_length, nodes = next_nodes, edges = next_edges)
    
#     bottom_nodes = (bom.edgeLength + 1) ** 2 * 4 - 4 * (bom.edgeLength + 1) +1
    
    
#    bottom_edges = 4 * bom.edges - 4 * bom.edgeLength
#    inverted_edges = bom.edges - 4 * bom.edgeLength
#    top_edges = bom.edges - 2 * (bom.edgeLength * (bom.edgeLength + 1))
#    edges =  bottom_edges + inverted_edges + top_edges
#    print(bottom_edges, inverted_edges, top_edges, edges)
    
    
    
    
 #   bottom_nodes = bom.nodes * 4 -  4 * bom.edgeLength - 3
  #  inverted_nodes = bom.nodes - 4 * bom.edgeLength - 1
   # top_nodes = bom.nodes - (bom.edgeLength + 1) ** 2
    #nodes = bottom_nodes+ inverted_nodes+ top_nodes
#     print(bottom_nodes, inverted_nodes, top_nodes, nodes)
    
    


    #return Bom(edgeLength = 2* bom.edgeLength, nodes = nodes, edges = edges)
    

  

    
 

second = nextIteration(first)
third = nextIteration(second)
fourth = nextIteration(third)
fifth = nextIteration(fourth)

print(first)
print(second)
print(third)
print(fourth)
print(fifth)
# Out:
# Bom(edgeLength=1, nodes=6, edges=12)
# Bom(edgeLength=2, nodes=19, edges=60)
# Bom(edgeLength=4, nodes=85, edges=336)
# Bom(edgeLength=8, nodes=457, edges=1968)
# Bom(edgeLength=16, nodes=2641, edges=11712)

# %%
import math



class CSNode:
    
    def __init__(self, x, y, connections=None):
        self.x = x
        self.y = y
        self.connections = connections if connections else {}

        
    
    



class LCS:
    
    def __init__(self):
        self.nodes = {}
        self.edges
        pass
    
    
    
    def


point1 = CSNode(0,0)
# Out:
#   File "<ipython-input-25-28d70ae1f29b>", line 27
#     def
#        ^
# SyntaxError: invalid syntax

# %%
()
